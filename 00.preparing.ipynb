# %% [markdown]
# <center>
#
# # 构建你的第一个人工智能项目
#
# </center>

# %% [markdown]
#
# <br>
# <br>
#
# </center>
#
# <div class="alert alert-block alert-success">
#  <b>Version:</b> v0.1 <b>Date:</b> 2020-07-25
#
# 在本课程中，我们将着手构建一个端到端的人工智能项目，回顾前述课程学习的内容，通过动手实践来强化对相关概念和知识的认识及了解。
# 希望对你未来的工作会有所帮助。
# </div>

# %% [markdown]
# # 背景

# %% [markdown]
# <br>
# <div class="alert alert-block alert-danger">
# <b>为什么会有这么一个课程？</b>
#
# - 人工智能是一门以实验为导向的学科；
# - 来自仪电，看到了很多仪电同事对人工智能的兴趣；
# - 我也是由于对AI本身充满兴趣，逐步学习和实践过来的，分享一些经验
# </div>

# %% [markdown]
# <br>
# <div class="alert alert-block alert-danger">
# <b>什么是一个端到端的人工智能项目？</b>
#
# - 中台 or pipeline？
# - 最佳实践有套路么？
# - 我们只有一下午的时间
#
# </div>

# %% [markdown]
# <br>
# <div class="alert alert-block alert-danger">
# <b>世界上每年有85%的AI项目最终以失败收场*，为什么？</b>
#
# - 希望这节课能够引起你的更多思考
#
# '* Pactera Technologies
#
#
# <details>
#
# - ML is still research, therefore it is very challenging to aim for 100% success rate.
#
# - Many ML projects are technically infeasible or poorly scoped.
#
# - Many ML projects never make the leap into production.
#
# - Many ML projects have unclear success criteria.
#
# - Many ML projects are poorly managed.
#
# </details>
#
# </div>

# %% [markdown]
# - 介绍助教|

# %% [markdown]
# # 目标

# %% [markdown]
# - 知识回顾

# %% [markdown]
# - 动手搭建一个端到端的人工智能项目

# %% [markdown]
# # 要求

# %% [markdown]
# - 动手实验，动起手来

# %% [markdown]
# - 遇到任何问题，不要犹豫，尽管讨论

# %% [markdown]
# # 提问

# %% [markdown]
# > 在坐的同学们，有谁尝试进行过神经网络的训练，或写过AI的模型？| 这个过程中，最痛苦的事情是什么？

# %% [markdown]
# # 人工智能实训平台
# # http://ailab.shaiic.com:8000/
